# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual, IntSlider, FloatSlider
import ipywidgets as widgets
import math
from Partition import Partition
from Approximation import ConstantApproximation, Approximation, LinearContApproximation
from ErrorMetrics import ErrorManager, MaxNorm

# %%
u = Partition.Uniform(0.0, 1.0, 16)
IL = LinearContApproximation(u, lambda x : x**0.5)
CL = ConstantApproximation(u, lambda x : x**0.5)

# %%
IL.plot()

# %%
CL.plot()

# %%
MaxNorm(interp)
